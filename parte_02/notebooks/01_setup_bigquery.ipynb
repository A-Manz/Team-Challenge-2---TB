# %% [markdown]
# # Setup BigQuery — NDIVIA
# Conexión a Google BigQuery y creación del dataset `ndivia`.

# %%
from google.cloud import bigquery
from google.oauth2 import service_account
import os
from dotenv import load_dotenv

load_dotenv()

# Configuración
PROJECT_ID = os.getenv("GCP_PROJECT_ID")
DATASET_ID = os.getenv("BQ_DATASET_ID")
CREDENTIALS_PATH = os.getenv("GOOGLE_APPLICATION_CREDENTIALS")

# Cliente autenticado
credentials = service_account.Credentials.from_service_account_file(
    CREDENTIALS_PATH
)
client = bigquery.Client(
    project=PROJECT_ID,
    credentials=credentials
)

# Crear dataset
dataset_ref = bigquery.Dataset(f"{PROJECT_ID}.{DATASET_ID}")
dataset_ref.location = "EU"  # Datos en Europa
dataset = client.create_dataset(dataset_ref, exists_ok=True)
print(f"Dataset {DATASET_ID} creado")
# Out:
# Dataset ndivia creado

# %%
# CUSTOMERS

table_customers = f"{PROJECT_ID}.{DATASET_ID}.customers"

schema = [
    bigquery.SchemaField("customer_id", "INT64"),
    bigquery.SchemaField("first_name", "STRING"),
    bigquery.SchemaField("last_name", "STRING"),
    bigquery.SchemaField("email", "STRING", mode="REQUIRED"),
    bigquery.SchemaField("phone", "STRING"),
    bigquery.SchemaField("country", "STRING"),
    bigquery.SchemaField("city", "STRING"),
    bigquery.SchemaField("acquisition_channel", "STRING"),
    bigquery.SchemaField("registration_date", "DATE"),
]

table = bigquery.Table(table_customers, schema=schema)
table = client.create_table(table, exists_ok=True)
print("Creada la tabla {}.{}.{}".format(table.project, table.dataset_id, table.table_id))
# Out:
# Creada la tabla ndivia-tc2.ndivia.customers

# %%
# CATEGORIES

table_categories = f"{PROJECT_ID}.{DATASET_ID}.categories"

schema = [
    bigquery.SchemaField("category_id", "INT64"),
    bigquery.SchemaField("category_name", "STRING"),
    bigquery.SchemaField("description", "STRING"),
]

table = bigquery.Table(table_categories, schema=schema)
table = client.create_table(table, exists_ok=True)
print("Creada la tabla {}.{}.{}".format(table.project, table.dataset_id, table.table_id))
# Out:
# Creada la tabla ndivia-tc2.ndivia.categories

# %%
# PRODUCTS

table_products = f"{PROJECT_ID}.{DATASET_ID}.products"

schema = [
    bigquery.SchemaField("product_id", "INT64"),
    bigquery.SchemaField("category_id", "INT64"),
    bigquery.SchemaField("product_name", "STRING"),
    bigquery.SchemaField("brand", "STRING"),
    bigquery.SchemaField("sale_price", "FLOAT64"),
    bigquery.SchemaField("cost", "FLOAT64"),
    bigquery.SchemaField("stock", "INT64"),
    bigquery.SchemaField("is_active", "BOOL", mode="REQUIRED"),
]

table = bigquery.Table(table_products, schema=schema)
table = client.create_table(table, exists_ok=True)
print("Creada la tabla {}.{}.{}".format(table.project, table.dataset_id, table.table_id))
# Out:
# Creada la tabla ndivia-tc2.ndivia.products

# %%
# ORDERS

table_orders = f"{PROJECT_ID}.{DATASET_ID}.orders"

schema = [
    bigquery.SchemaField("order_id", "INT64"),
    bigquery.SchemaField("customer_id", "INT64"),
    bigquery.SchemaField("order_status", "STRING"),
    bigquery.SchemaField("order_date", "TIMESTAMP"),
    bigquery.SchemaField("shipped_at", "TIMESTAMP"),
    bigquery.SchemaField("delivered_at", "TIMESTAMP"),
    bigquery.SchemaField("shipping_country", "STRING"),
    bigquery.SchemaField("shipping_city", "STRING"),
    bigquery.SchemaField("shipping_address", "STRING"),
    bigquery.SchemaField("shipping_postal_code", "STRING"),
    bigquery.SchemaField("order_total", "FLOAT64"),
]

table = bigquery.Table(table_orders, schema=schema)
table = client.create_table(table, exists_ok=True)
print("Creada la tabla {}.{}.{}".format(table.project, table.dataset_id, table.table_id))
# Out:
# Creada la tabla ndivia-tc2.ndivia.orders

# %%
# PAYMENTS

table_payments = f"{PROJECT_ID}.{DATASET_ID}.payments"

schema = [
    bigquery.SchemaField("payment_id", "INT64"),
    bigquery.SchemaField("order_id", "INT64"),
    bigquery.SchemaField("payment_method", "STRING"),
    bigquery.SchemaField("payment_status", "STRING"),
    bigquery.SchemaField("amount", "FLOAT64"),
    bigquery.SchemaField("payment_date", "TIMESTAMP"),
    bigquery.SchemaField("refunded_amount", "FLOAT64"),
]

table = bigquery.Table(table_payments, schema=schema)
table = client.create_table(table, exists_ok=True)
print("Creada la tabla {}.{}.{}".format(table.project, table.dataset_id, table.table_id))
# Out:
# Creada la tabla ndivia-tc2.ndivia.payments

# %%
# ORDER_ITEMS

table_order_items = f"{PROJECT_ID}.{DATASET_ID}.order_items"

schema = [
    bigquery.SchemaField("order_item_id", "INT64"),
    bigquery.SchemaField("order_id", "INT64"),
    bigquery.SchemaField("product_id", "INT64"),
    bigquery.SchemaField("quantity", "INT64"),
    bigquery.SchemaField("unit_price", "FLOAT64"),
    bigquery.SchemaField("discount_pct", "FLOAT64"),
    bigquery.SchemaField("line_total", "FLOAT64"),
]

table = bigquery.Table(table_order_items, schema=schema)
table = client.create_table(table, exists_ok=True)
print("Creada la tabla {}.{}.{}".format(table.project, table.dataset_id, table.table_id))
# Out:
# Creada la tabla ndivia-tc2.ndivia.order_items

# %%
# REVIEWS

table_reviews = f"{PROJECT_ID}.{DATASET_ID}.reviews"

schema = [
    bigquery.SchemaField("review_id", "INT64"),
    bigquery.SchemaField("order_item_id", "INT64"),
    bigquery.SchemaField("customer_id", "INT64"),
    bigquery.SchemaField("product_id", "INT64"),
    bigquery.SchemaField("rating", "INT64"),
    bigquery.SchemaField("comment", "STRING"),
    bigquery.SchemaField("review_date", "TIMESTAMP"),
]

table = bigquery.Table(table_reviews, schema=schema)
table = client.create_table(table, exists_ok=True)
print("Creada la tabla {}.{}.{}".format(table.project, table.dataset_id, table.table_id))
# Out:
# Creada la tabla ndivia-tc2.ndivia.reviews
