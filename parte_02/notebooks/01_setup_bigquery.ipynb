# %% [markdown]
# # Setup BigQuery — NDIVIA
# Conexión a Google BigQuery y creación del dataset `ndivia`.

# %%
from google.cloud import bigquery
from google.oauth2 import service_account
import os
from dotenv import load_dotenv

load_dotenv()

# Configuración
PROJECT_ID = os.getenv("GCP_PROJECT_ID")
DATASET_ID = os.getenv("BQ_DATASET_ID")
CREDENTIALS_PATH = os.getenv("GOOGLE_APPLICATION_CREDENTIALS")

# Cliente autenticado
credentials = service_account.Credentials.from_service_account_file(
    CREDENTIALS_PATH
)
client = bigquery.Client(
    project=PROJECT_ID,
    credentials=credentials
)

# Crear dataset
dataset_ref = bigquery.Dataset(f"{PROJECT_ID}.{DATASET_ID}")
dataset_ref.location = "EU"  # Datos en Europa
dataset = client.create_dataset(dataset_ref, exists_ok=True)
print(f"Dataset {DATASET_ID} creado")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 14
#      10 DATASET_ID = os.getenv("BQ_DATASET_ID")
#      11 CREDENTIALS_PATH = os.getenv("GOOGLE_APPLICATION_CREDENTIALS")
#      12
#      13 # Cliente autenticado
# ---> 14 credentials = service_account.Credentials.from_service_account_file(
#      15     CREDENTIALS_PATH
#      16 )
#      17 client = bigquery.Client(
#
# File c:\Users\ramir\Documents\GitHub\marzo\TeamChallenges\Team-Challenge-2---TB\parte_02\venv\Lib\site-packages\google\oauth2\service_account.py:270, in Credentials.from_service_account_file(cls, filename, **kwargs)
#     258 @classmethod
#     259 def from_service_account_file(cls, filename, **kwargs):
#     260     """Creates a Credentials instance from a service account json file.
#     261
#     262     Args:
#    (...)    268             credentials.
#     269     """
# --> 270     info, signer = _service_account_info.from_filename(
#     271         filename, require=["client_email", "token_uri"]
#     272     )
#     273     return cls._from_signer_and_info(signer, info, **kwargs)
#
# File c:\Users\ramir\Documents\GitHub\marzo\TeamChallenges\Team-Challenge-2---TB\parte_02\venv\Lib\site-packages\google\auth\_service_account_info.py:78, in from_filename(filename, require, use_rsa_signer)
#      64 def from_filename(filename, require=None, use_rsa_signer=True):
#      65     """Reads a Google service account JSON file and returns its parsed info.
#      66
#      67     Args:
#    (...)     76             info and a signer instance.
#      77     """
# ---> 78     with io.open(filename, "r", encoding="utf-8") as json_file:
#      79         data = json.load(json_file)
#      80         return data, from_dict(data, require=require, use_rsa_signer=use_rsa_signer)
#
# FileNotFoundError: [Errno 2] No such file or directory: './credentials/service-account.json'
